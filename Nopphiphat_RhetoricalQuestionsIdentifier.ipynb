# %% [markdown]
# # Homework #1

# %% [markdown]
# Analyzing presidential debate texts to DETERMINE rhetorical questions, which is a sentence that is a question, but that is not answered by another speaker, IDENTIFY who said the rhetorical question, and IDENTIFY what the response to the question was.
#
# Rhetorical questions will typically occur in one speaker's speech and not be followed by someone else responding. Examples of rhetorical questions:
#
# 1) And I said, "Why won't everybody go south?" They say, "It would be disruptive."
#
# 2) I said, "For how long?" I finally got them up for 12 to 15 years.
#
# 3) And I said, "Well, how does it stop being disruptive?" And that is, when their jobs come up from  1𝑎𝑛ℎ𝑜𝑢𝑟𝑡𝑜 6 an hour, and ours go down to $6 an hour, then it's leveled again.

# %%
import re, nltk
from os import listdir
from os.path import isfile, join
from nltk import data
from nltk.util import bigrams
from nltk.tokenize import TreebankWordTokenizer, word_tokenize
nltk.download('punkt')
sentence_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
treebank_tokenizer = TreebankWordTokenizer()

dir_base = "/Users/HyunjaeCho/Documents/GitHub/f19_ds_nlp/homeworks/homework_1/data/"
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/HyunjaeCho/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def read_file(filename):
    input_file_text = open(filename, encoding = 'utf-8').read()
    return input_file_text

def read_directory_files(directory):
    file_texts = []
    files = [f for f in listdir(directory) if isfile(join(directory, f))]
    #print(files)
    for f in files:
        file_text = read_file(join(directory, f))
        #print(file_text)
        file_texts.append({"file": f, "content": file_text})
    return file_texts

# %% [markdown]
# Read all files into dictionary within list.
# Each element in the list is a dictionary with two elements: file, content
#
# which can be accessed by: list[dictionary_number][dictionary_element].
#
# 1) text_corpus[0] - first dictionary element of list 'text_corpus'
#
# 2) text_corpus[0][file] - first dictionary element's file of list 'text_corpus'
#
# 3) text_corpus[0][content] - first dictionary element's content of list 'text_corpus'

# %%
text_corpus = read_directory_files(dir_base)
print(text_corpus)
# Out:
# [{'file': '88_debate_1', 'content': 'LEHRER: Good evening. On behalf of the Commission on Presidential Debates I am pleased to welcome you to this first presidential debate of the 1988 campaign. I\'m Jim Lehrer of the McNeil-Lehrer News Hour. My colleagues on the panel are John Mashek of The Atlanta Journal-Constitution; Ann Groer of The Orlando Sentinel; and Peter Jennings of ABC News. For the next 90 minutes we will be questioning the candidates for president of the United States following a format designed and agreed to by representatives of the two candidates. The candidates are Vice President George Bush, the Republican nominee; Governor Michael Dukakis, the Democratic nominee.\n\n(Applause)\n\nLEHRER: Our questions this evening will be about equally divided between foreign and domestic policy matters. The first question by agreement between the two candidates goes to Vice President Bush. It is a domestic question. You have two minutes for an answer, sir. The polls say the numbe
# ...

# %%
def process_debate(debate_object):
    
    number_of_debates = len(debate_object)
    list_of_debates = []
    possible_rhetorical_questions = []
    all_words = []
    for i in range(number_of_debates):
        debate_name = debate_object[i]
        debate_text = debate_name["content"]
        list_of_debates.append(debate_object[i]["content"])
    
    all_sentences = list_of_debates[0] + " " + list_of_debates[1] + " " +  list_of_debates[2] + " " + list_of_debates[3] + " " + list_of_debates[4] + " " + list_of_debates[5]
    tokenized_words = treebank_tokenizer.tokenize(all_sentences)
    tokenized_sentences = sentence_tokenizer.tokenize(all_sentences)
    
    for i in tokenized_sentences:
        check = re.findall(r'\s*([^.?]*(?:[hH]ow|[cC]an|[wW]hat|[wW]here|[dD]escribe|[wW]ho|[wW]hen)[^.?]*?\s*\?)', i)
        for s in check:
            possible_rhetorical_questions.append(s)
    
    return possible_rhetorical_questions, tokenized_sentences, tokenized_words, all_sentences

# %%
# Process the debates and output possible_rhetorical_questions, tokenized_sentence, tokenized_words, and all_sentences
possible_rhetorical_questions, tokenized_sentences, tokenized_words, all_sentences = process_debate(text_corpus)

# %%
num_tokenized_sentences = len(tokenized_sentences)
num_possible_rhetorical_questions = len(possible_rhetorical_questions)
num_tokenized_words = len(tokenized_words)

print("Number of tokenized sentences = " + str(num_tokenized_sentences) + "\n---")
print("Number of possible rhetorical sentences = " + str(num_possible_rhetorical_questions) + "\n---")
print("Number of tokenized words = " + str(num_tokenized_words))
# Out:
# Number of tokenized sentences = 5903
# ---
# Number of possible rhetorical sentences = 214
# ---
# Number of tokenized words = 100837

# %%
print(tokenized_words)
# Out:
# ['LEHRER', ':', 'Good', 'evening.', 'On', 'behalf', 'of', 'the', 'Commission', 'on', 'Presidential', 'Debates', 'I', 'am', 'pleased', 'to', 'welcome', 'you', 'to', 'this', 'first', 'presidential', 'debate', 'of', 'the', '1988', 'campaign.', 'I', "'m", 'Jim', 'Lehrer', 'of', 'the', 'McNeil-Lehrer', 'News', 'Hour.', 'My', 'colleagues', 'on', 'the', 'panel', 'are', 'John', 'Mashek', 'of', 'The', 'Atlanta', 'Journal-Constitution', ';', 'Ann', 'Groer', 'of', 'The', 'Orlando', 'Sentinel', ';', 'and', 'Peter', 'Jennings', 'of', 'ABC', 'News.', 'For', 'the', 'next', '90', 'minutes', 'we', 'will', 'be', 'questioning', 'the', 'candidates', 'for', 'president', 'of', 'the', 'United', 'States', 'following', 'a', 'format', 'designed', 'and', 'agreed', 'to', 'by', 'representatives', 'of', 'the', 'two', 'candidates.', 'The', 'candidates', 'are', 'Vice', 'President', 'George', 'Bush', ',', 'the', 'Republican', 'nominee', ';', 'Governor', 'Michael', 'Dukakis', ',', 'the', 'Democratic', 'nominee.', '('
# ...

# %%
question_index = []
colon_index = []
for i in range(num_tokenized_words):
    if re.match(r'[\?]', tokenized_words[i]):
        #print(tokenized_words[i])
        question_index.append(i)
    if re.match(r'[\:]', tokenized_words[i]):
        #print(tokenized_words[i])
        colon_index.append(i)
print("Number of question symbols = " + str(len(question_index)) + "\n---")
print("Number of colon symbols = " + str(len(colon_index)) + "\n---")
#print(question_index)
#print(colon_index)
# Out:
# Number of question symbols = 426
# ---
# Number of colon symbols = 319
# ---
# ...

# %%
speakers = []
speakers_index = []
for i in colon_index:
    #print(tokenized_words[i-2] + " " + tokenized_words[i-1] + "\n")
    if re.match(r'([^a-z\d]+[A-Z]+)', tokenized_words[i-1]):
        if re.match(r'([^a-z\d]+[A-Z]+)', tokenized_words[i-2]):
            if re.match(r'([^a-z\d]+[A-Z]+)', tokenized_words[i-3]):
                if re.match(r'([^a-z\d]+[A-Z]+)', tokenized_words[i-4]):
                    if re.match(r'([^a-z\d]+[A-Z]+)', tokenized_words[i-5]):
                        if re.match(r'([^a-z\d]+[A-Z]+)', tokenized_words[i-6]):
                            six = tokenized_words[i-6] + " " + tokenized_words[i-5] + " " + tokenized_words[i-4] + " " + tokenized_words[i-3] + " " + tokenized_words[i-2] + " " + tokenized_words[i-1]
                            #if six != string.empty:
                            speakers_index.append(i-6)
                            if six not in speakers:
                                speakers.append(six)
                        if re.match(r'([^A-Z]+)', tokenized_words[i-6]): 
                            quintuple = tokenized_words[i-5] + " " + tokenized_words[i-4] + " " + tokenized_words[i-3] + " " + tokenized_words[i-2] + " " + tokenized_words[i-1]
                            #if quintuple != string.empty:
                            speakers_index.append(i-5)
                            if quintuple not in speakers:
                                speakers.append(quintuple)
                    if re.match(r'([^A-Z]+)', tokenized_words[i-5]): 
                        quadruple = tokenized_words[i-4] + " " + tokenized_words[i-3] + " " + tokenized_words[i-2] + " " + tokenized_words[i-1]
                        #if quadruple != string.empty:
                        speakers_index.append(i-4)
                        if quadruple not in speakers:
                            speakers.append(quadruple)
                if re.match(r'([^A-Z]+)', tokenized_words[i-4]): 
                    triple = tokenized_words[i-3] + " " + tokenized_words[i-2] + " " + tokenized_words[i-1]
                    #if triple != string.empty:
                    speakers_index.append(i-3)
                    if triple not in speakers:
                        speakers.append(triple)
            if re.match(r'([^A-Z]+)', tokenized_words[i-3]):     
                double = tokenized_words[i-2] + " " + tokenized_words[i-1]
                #if double != string.empty:
                speakers_index.append(i-2)
                if double not in speakers:
                    speakers.append(double)
        if re.match(r'([^A-Z]+)', tokenized_words[i-2]):    
            single = tokenized_words[i-1]
            #if single != string.empty:
            speakers_index.append(i-1)
            if single not in speakers:
                speakers.append(single)
print(speakers)
print(speakers_index)
for i in speakers_index:
    print(tokenized_words[i] + "\n")
# Out:
# ['LEHRER', 'BUSH', 'DUKAKIS', 'MASHEK', 'GROER', 'JENNINGS', 'D.C. LEHRER', 'LEAGUE OF WOMEN VOTERS EDUCATION FUND', 'PUBLIC BROADCASTING SYSTEM', 'FORTUNE MAGAZINE', 'MOYERS', 'LOOMIS', 'GOV. RONALD REAGAN', 'REAGAN', 'ANDERSON', 'SYNDICATED COLUMNIST', 'BALTIMORE', 'CORDDRY', 'WASHINGTON BUREAU', 'MAY', 'CBS NEWS/NEWSWEEK /WASHINGTON POST', 'POST', 'THE NEW YORK TIMES']
# ...

# %%
for sentence in tokenized_sentences:
    print(sentence + "\n")
# Out:
# LEHRER: Good evening.
#
# On behalf of the Commission on Presidential Debates I am pleased to welcome you to this first presidential debate of the 1988 campaign.
#
# I'm Jim Lehrer of the McNeil-Lehrer News Hour.
#
# My colleagues on the panel are John Mashek of The Atlanta Journal-Constitution; Ann Groer of The Orlando Sentinel; and Peter Jennings of ABC News.
#
# For the next 90 minutes we will be questioning the candidates for president of the United States following a format designed and agreed to by representatives of the two candidates.
#
# The candidates are Vice President George Bush, the Republican nominee; Governor Michael Dukakis, the Democratic nominee.
#
# (Applause)
#
# LEHRER: Our questions this evening will be about equally divided between foreign and domestic policy matters.
#
# The first question by agreement between the two candidates goes to Vice President Bush.
#
# It is a domestic question.
#
# You have two minutes for an answer, sir.
#
# ...

# %%
# Remove duplicates within list of possible rhetorical questions
temp = []
for i in possible_rhetorical_questions:
    if i not in temp:
        temp.append(i) 
num_possible_rhetorical_questions = temp
print(len(num_possible_rhetorical_questions))
# Out:
# 210

# %%
# Find the indexes for all the sentences within tokenized_sentences
# that match all questions inside the possible_rhetorical_questions
possible_rhetorical_questions_index = []
for question in possible_rhetorical_questions:
    if question in tokenized_sentences:
        x = tokenized_sentences.index(question)
        possible_rhetorical_questions_index.append(x)
print(len(possible_rhetorical_questions_index))
print(possible_rhetorical_questions_index)
#print(debate_sentences[26])
# Out:
# 188
# ...

# %%
candidate_rhetorical_questions_index = []
for i in possible_rhetorical_questions_index:
    prev_sentence = tokenized_sentences[i-1] 
    next_sentence = tokenized_sentences[i+1]
    #print(prev_sentence + "\n")
    if ((re.match('^[A-Z][^?!.]*[.!]$', next_sentence)) and (re.match('^(?![A-Z]+(\s)[A-Z]+\.)', next_sentence)) and (re.match('^(?!([A-Z][a-z]+|[A-Z]+)\.)', next_sentence)) and (re.match('^(?![A-Z][a-z]+(\s)+[A-Z][a-z]+\.)', next_sentence)) and (re.match('^(?![A-Z]+\:)', next_sentence)) and (re.match('^[A-Z][^?!.]*[.!]$', prev_sentence))):        
        candidate_rhetorical_questions_index.append(i)
        #print(i)
print(len(candidate_rhetorical_questions_index))
print(candidate_rhetorical_questions_index)
# Out:
# 41
# [391, 393, 862, 1157, 1160, 1394, 1468, 1485, 1542, 1551, 1553, 1570, 1628, 1678, 1754, 1843, 1975, 1983, 2114, 2116, 2125, 2357, 2509, 2653, 3338, 3358, 3380, 3385, 3418, 3494, 3551, 3878, 4017, 4193, 4397, 4499, 4549, 4744, 4749, 5176, 5465]

# %%
clean_rhetorical_questions = []
for i in candidate_rhetorical_questions_index:
    #print(tokenized_sentences[i] + "\n")
    #print(tokenized_sentences[i-1] + " " + tokenized_sentences[i] + " " + tokenized_sentences[i+1] + "\n")
    clean_rhetorical_questions.append(tokenized_sentences[i])
    
print(clean_rhetorical_questions)
# Out:
# ['When you talk to those bankers, did they discuss where interest rates were when your party controlled the White House?', 'Now, how does that grab you for increasing housing?', 'What kind of judgment sense has your chief education adviser now in jail in Massachusetts?', "What I have been advocating is, why don't we start with the Federal Government turning back tax sources to states and local governments, as well as the responsibilities for those programs?", 'But, where are we getting the money that the Federal Government is putting out to help them?', 'The issue of our natural resources; the right of posterity to inherit the earth, and what kind of earth will it be?', 'So what is the answer?', 'Would you define in specific dollar goals how much you would reduce the deficit in each of the 4 years of a Clinton administration and then enter into a legally binding contract with the American people that if you did not achieve those goals that you would not seek a second term?', "What I'
# ...

# %%
speaker_sentences = []
for i in range(num_tokenized_sentences):
    for name in speakers:
        if name in tokenized_sentences[i]:
            #print(tokenized_sentences[i])
            speaker_sentences.append(i)
print("Indexes of sentences with speakers: " + "\n")
print(speaker_sentences)
print("\n" + "Indexes of sentences that are rhetorical questions" + "\n")
print(candidate_rhetorical_questions_index)
# Out:
# Indexes of sentences with speakers:
#
# ...

# %%
speaker_rhetorical = []
for i in range(len(candidate_rhetorical_questions_index)):
    speaker_sentence_index = min(speaker_sentences, key=lambda x:abs(x-candidate_rhetorical_questions_index[i]))
    speaker_sentence = tokenized_sentences[speaker_sentence_index]
    #print(speaker_sentence)
    #print(tokenized_sentences[candidate_rhetorical_questions_index[i]])
    for name in speakers:
        if name in speaker_sentence:
            speaker_rhetorical.append({"speaker": name, "questions": tokenized_sentences[candidate_rhetorical_questions_index[i]]})
#print(speaker_rhetorical)
print(str(len(speaker_rhetorical)) + " rhetorical questions" + "\n")

for i in range(len(speaker_rhetorical)):
    print(speaker_rhetorical[i])
    print("\n")
# Out:
# 41 rhetorical questions
#
# {'speaker': 'BUSH', 'questions': 'When you talk to those bankers, did they discuss where interest rates were when your party controlled the White House?'}
#
#
# {'speaker': 'BUSH', 'questions': 'Now, how does that grab you for increasing housing?'}
#
#
# {'speaker': 'LEHRER', 'questions': 'What kind of judgment sense has your chief education adviser now in jail in Massachusetts?'}
#
#
# {'speaker': 'REAGAN', 'questions': "What I have been advocating is, why don't we start with the Federal Government turning back tax sources to states and local governments, as well as the responsibilities for those programs?"}
#
#
# {'speaker': 'REAGAN', 'questions': 'But, where are we getting the money that the Federal Government is putting out to help them?'}
#
#
# {'speaker': 'MOYERS', 'questions': 'The issue of our natural resources; the right of posterity to inherit the earth, and what kind of earth will it be?'}
#
#
# ...
